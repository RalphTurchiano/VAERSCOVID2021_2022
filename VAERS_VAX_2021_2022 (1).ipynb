# %%
import pandas as pd
import csv
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Source VAERS: https://vaers.hhs.gov/data/datasets.html
# Sources COVID VACCINE TRENDS : https://data.cdc.gov/Vaccinations/COVID-19-Vaccination-Trends-in-the-United-States-N/rh2h-3yt2

# %%
Vac_Dist = pd.read_csv("COVID-19_Vaccination_Trends.csv", encoding='latin1')

# %%
Vac_Dist.columns
# Out:
# Index(['Date', 'date_type', 'MMWR_week', 'Location', 'Administered_Daily',
#        'Administered_Cumulative', 'Administered_7_Day_Rolling_Average',
#        'Admin_Dose_1_Daily', 'Admin_Dose_1_Cumulative',
#        'Admin_Dose_1_Day_Rolling_Average', 'Administered_Dose1_Pop_Pct',
#        'Administered_daily_change_report',
#        'Administered_daily_change_report_7dayroll', 'Series_Complete_Daily',
#        'Series_Complete_Cumulative', 'Series_Complete_Day_Rolling_Average',
#        'Series_Complete_Pop_Pct', 'Booster_Daily', 'Booster_Cumulative',
#        'Booster_7_Day_Rolling_Average', 'Additional_Doses_Vax_Pct',
#        'Second_Booster_50Plus_Daily', 'Second_Booster_50Plus_Cumulative',
#        'Second_Booster_50Plus_7_Day_Rolling_Average',
#        'Second_Booster_50Plus_Vax_Pct', 'Bivalent_Booster_Daily',
#        'Bivalent_Booster_Cumulative', 'Bivalent_Booster_7_Day_Rolling_Average',
#        'Bivalent_Booster_Pop_Pct'],
#       dtype='object')

# %%
VaxUS = Vac_Dist[Vac_Dist['Location'] == 'US']

# %%
Vac_Dist[Vac_Dist['Date'].isin(['12/31/2022']) & Vac_Dist['Location'].isin(['US'])]
# Out:
#             Date date_type  MMWR_week Location  Administered_Daily  \
# 1720  12/31/2022     Admin         52       US               62134
#
#       Administered_Cumulative  Administered_7_Day_Rolling_Average  \
# 1720                665633098                            170435.0
#
#       Admin_Dose_1_Daily  Admin_Dose_1_Cumulative  \
# 1720                9651                268451387
#
#       Admin_Dose_1_Day_Rolling_Average  ...  Booster_7_Day_Rolling_Average  \
# 1720                           24494.0  ...                        26486.0
#
#       Additional_Doses_Vax_Pct  Second_Booster_50Plus_Daily  \
# 1720                      50.8                        13859
#
#       Second_Booster_50Plus_Cumulative  \
# 1720                          34852698
#
#       Second_Booster_50Plus_7_Day_Rolling_Average  \
# 1720                                      36902.0
#
#       Second_Booster_50Plus_Vax_Pct  Bivalent_Booster_Daily  \
# 1720                           50.9                   58335
#
#       Bivalent_Booster_Cumulative  Bivalent_Booster_7_Day_Rolling_Average  \
# 1720                     48669790                                153676.0
#
#       Bivalent_Booster_Pop_Pct
# 1720                      14.7
#
# [1 rows x 29 columns]

# %%
Vax_Hist_US = pd.DataFrame()
Vax_Hist_US[['Date','date_type','Administered_Daily','Administered_Cumulative','Administered_7_Day_Rolling_Average']] = VaxUS[['Date','date_type','Administered_Daily','Administered_Cumulative','Administered_7_Day_Rolling_Average']]
Vax_Hist_US.info()
Vax_Hist_US['Date'] = pd.to_datetime(Vax_Hist_US['Date'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1356 entries, 36 to 81338
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Date                                1356 non-null   object
#  1   date_type                           1356 non-null   object
#  2   Administered_Daily                  1356 non-null   int64
#  3   Administered_Cumulative             1356 non-null   int64
#  4   Administered_7_Day_Rolling_Average  1324 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 63.6+ KB

# %%
Vax_Hist_US['date_type'].value_counts()
# Out:
# Admin     773
# Report    583
# Name: date_type, dtype: int64

# %%
Vax_Hist_US_Y= Vax_Hist_US[Vax_Hist_US['date_type'].isin(['Admin'])]

# %%
Vax_Hist_US_Z = Vax_Hist_US_Y.copy()

# %%
Vax_Hist_US_Z['Administered_7_Day_Rolling_Average'] = Vax_Hist_US_Z['Administered_7_Day_Rolling_Average'].astype(int).copy()

# %%
Vax_Hist_US_Z.drop('date_type',axis=1, inplace=True)

# %%
Vax_Hist_US= Vax_Hist_US_Z.copy()

# %%
Vax_Hist_US.rename(columns= {'Date':'VAX_DATE'}, inplace=True)

# %%
Vax_Hist_US  = Vax_Hist_US[(Vax_Hist_US['VAX_DATE'] > '2020-12-31') & (Vax_Hist_US['VAX_DATE'] <= '2022-12-30')]

# %%
Vax_Hist_US.to_csv('Vax_Hist_US.csv')

# %%
Vax_Hist_US
# Out:
#         VAX_DATE  Administered_Daily  Administered_Cumulative  \
# 1750  2022-12-30              238624                665570964
# 1802  2022-12-29              259886                665332340
# 1903  2022-12-28              257657                665072454
# 2008  2022-12-27              263316                664814797
# 2040  2022-12-26              109048                664551481
# ...          ...                 ...                      ...
# 78599 2021-01-05              839381                  7750452
# 78654 2021-01-04              664563                  6911071
# 78779 2021-01-03              141161                  6246508
# 78881 2021-01-02              268446                  6105347
# 78999 2021-01-01              131486                  5836901
#
#        Administered_7_Day_Rolling_Average
# 1750                               167073
# 1802                               154653
# 1903                               149758
# 2008                               153697
# 2040                               160791
# ...                                   ...
# 78599                              474104
# 78654                              458244
# 78779                              448544
# 78881                              442198
# 78999                              424324
#
# [729 rows x 4 columns]

# %%
Vac_Dist = pd.read_csv("COVID-19_Vaccination_Trends.csv", encoding='latin1')

# %%
Vac_Dist.columns
# Out:
# Index(['Date', 'date_type', 'MMWR_week', 'Location', 'Administered_Daily',
#        'Administered_Cumulative', 'Administered_7_Day_Rolling_Average',
#        'Admin_Dose_1_Daily', 'Admin_Dose_1_Cumulative',
#        'Admin_Dose_1_Day_Rolling_Average', 'Administered_Dose1_Pop_Pct',
#        'Administered_daily_change_report',
#        'Administered_daily_change_report_7dayroll', 'Series_Complete_Daily',
#        'Series_Complete_Cumulative', 'Series_Complete_Day_Rolling_Average',
#        'Series_Complete_Pop_Pct', 'Booster_Daily', 'Booster_Cumulative',
#        'Booster_7_Day_Rolling_Average', 'Additional_Doses_Vax_Pct',
#        'Second_Booster_50Plus_Daily', 'Second_Booster_50Plus_Cumulative',
#        'Second_Booster_50Plus_7_Day_Rolling_Average',
#        'Second_Booster_50Plus_Vax_Pct', 'Bivalent_Booster_Daily',
#        'Bivalent_Booster_Cumulative', 'Bivalent_Booster_7_Day_Rolling_Average',
#        'Bivalent_Booster_Pop_Pct'],
#       dtype='object')

# %%
VaxUS = Vac_Dist[Vac_Dist['Location'] == 'US']

# %%
Vac_Dist[Vac_Dist['Date'].isin(['12/31/2022']) & Vac_Dist['Location'].isin(['US'])]
# Out:
#             Date date_type  MMWR_week Location  Administered_Daily  \
# 1720  12/31/2022     Admin         52       US               62134
#
#       Administered_Cumulative  Administered_7_Day_Rolling_Average  \
# 1720                665633098                            170435.0
#
#       Admin_Dose_1_Daily  Admin_Dose_1_Cumulative  \
# 1720                9651                268451387
#
#       Admin_Dose_1_Day_Rolling_Average  ...  Booster_7_Day_Rolling_Average  \
# 1720                           24494.0  ...                        26486.0
#
#       Additional_Doses_Vax_Pct  Second_Booster_50Plus_Daily  \
# 1720                      50.8                        13859
#
#       Second_Booster_50Plus_Cumulative  \
# 1720                          34852698
#
#       Second_Booster_50Plus_7_Day_Rolling_Average  \
# 1720                                      36902.0
#
#       Second_Booster_50Plus_Vax_Pct  Bivalent_Booster_Daily  \
# 1720                           50.9                   58335
#
#       Bivalent_Booster_Cumulative  Bivalent_Booster_7_Day_Rolling_Average  \
# 1720                     48669790                                153676.0
#
#       Bivalent_Booster_Pop_Pct
# 1720                      14.7
#
# [1 rows x 29 columns]

# %%
Vax_Hist_US = pd.DataFrame()
Vax_Hist_US[['Date','date_type','Administered_Daily','Administered_Cumulative','Administered_7_Day_Rolling_Average']] = VaxUS[['Date','date_type','Administered_Daily','Administered_Cumulative','Administered_7_Day_Rolling_Average']]
Vax_Hist_US.info()
Vax_Hist_US['Date'] = pd.to_datetime(Vax_Hist_US['Date'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1356 entries, 36 to 81338
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Date                                1356 non-null   object
#  1   date_type                           1356 non-null   object
#  2   Administered_Daily                  1356 non-null   int64
#  3   Administered_Cumulative             1356 non-null   int64
#  4   Administered_7_Day_Rolling_Average  1324 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 63.6+ KB

# %%
Vax_Hist_US['date_type'].value_counts()
# Out:
# Admin     773
# Report    583
# Name: date_type, dtype: int64

# %%
Vax_Hist_US_Y= Vax_Hist_US[Vax_Hist_US['date_type'].isin(['Admin'])]

# %%
Vax_Hist_US_Z = Vax_Hist_US_Y.copy()

# %%
Vax_Hist_US_Z['Administered_7_Day_Rolling_Average'] = Vax_Hist_US_Z['Administered_7_Day_Rolling_Average'].astype(int).copy()

# %%
Vax_Hist_US_Z.drop('date_type',axis=1, inplace=True)

# %%
Vax_Hist_US= Vax_Hist_US_Z.copy()

# %%
Vax_Hist_US.rename(columns= {'Date':'VAX_DATE'}, inplace=True)

# %%
Vax_Hist_US  = Vax_Hist_US[(Vax_Hist_US['VAX_DATE'] > '2020-12-31') & (Vax_Hist_US['VAX_DATE'] <= '2022-12-30')]

# %%
Vax_Hist_US.to_csv('Vax_Hist_US.csv')

# %%
Vax_Hist_US
# Out:
#         VAX_DATE  Administered_Daily  Administered_Cumulative  \
# 1750  2022-12-30              238624                665570964
# 1802  2022-12-29              259886                665332340
# 1903  2022-12-28              257657                665072454
# 2008  2022-12-27              263316                664814797
# 2040  2022-12-26              109048                664551481
# ...          ...                 ...                      ...
# 78599 2021-01-05              839381                  7750452
# 78654 2021-01-04              664563                  6911071
# 78779 2021-01-03              141161                  6246508
# 78881 2021-01-02              268446                  6105347
# 78999 2021-01-01              131486                  5836901
#
#        Administered_7_Day_Rolling_Average
# 1750                               167073
# 1802                               154653
# 1903                               149758
# 2008                               153697
# 2040                               160791
# ...                                   ...
# 78599                              474104
# 78654                              458244
# 78779                              448544
# 78881                              442198
# 78999                              424324
#
# [729 rows x 4 columns]

# %%
VAXUS = pd.read_csv("Vax_Hist_US.csv", encoding='latin1')

# %%
VAX2021 = pd.read_csv("2021VAERSVAX.csv", encoding='latin1')
VAX2022 = pd.read_csv("2022VAERSVAX.csv", encoding='latin1')
SYM2021 = pd.read_csv("2021VAERSSYMPTOMS.csv", encoding='latin1')
SYM2022 = pd.read_csv("2022VAERSSYMPTOMS.csv", encoding='latin1')

# %%
import csv

with open("2022VAERSData.csv", mode="r") as old_file:
    reader_obj = csv.reader(old_file)

    with open("2022VAERSDataX.csv", mode="w") as new_file:
        writer_obj = csv.writer(new_file, delimiter=",")

        for data in reader_obj:
            writer_obj.writerow(data)

# %%
with open("2021VAERSDATA.csv", mode="r") as old_file:
    reader_obj = csv.reader(old_file)

    with open("2021VAERSDATAX.csv", mode="w") as new_file:
        writer_obj = csv.writer(new_file, delimiter=",")

        for data in reader_obj:
            writer_obj.writerow(data)

# %%
VDATA2021 = pd.read_csv("2021VAERSDATAX.csv", encoding ='latin1',low_memory = False)
VDATA2022 = pd.read_csv("2022VAERSDATAX.csv", encoding ='latin1',low_memory = False)

# %%
V2021 = SYM2021.merge(VAX2021,on='VAERS_ID', how='inner')
DUP2021 = V2021[V2021.duplicated(subset='VAERS_ID', keep=False)]
V2022 = SYM2022.merge(VAX2022,on='VAERS_ID', how='inner')
DUP2022 = V2022[V2022.duplicated(subset='VAERS_ID', keep=False)]

# %%
V2021_B = V2021.merge(VDATA2021,on='VAERS_ID', how='inner')
V2022_B = V2022.merge(VDATA2022,on='VAERS_ID', how='inner')

# %%
ind ={}
for x in V2022_B.columns:
    ind[x] = V2022_B.columns.get_loc(x)
print(ind)
# Out:
# {'VAERS_ID': 0, 'SYMPTOM1': 1, 'SYMPTOMVERSION1': 2, 'SYMPTOM2': 3, 'SYMPTOMVERSION2': 4, 'SYMPTOM3': 5, 'SYMPTOMVERSION3': 6, 'SYMPTOM4': 7, 'SYMPTOMVERSION4': 8, 'SYMPTOM5': 9, 'SYMPTOMVERSION5': 10, 'VAX_TYPE': 11, 'VAX_MANU': 12, 'VAX_LOT': 13, 'VAX_DOSE_SERIES': 14, 'VAX_ROUTE': 15, 'VAX_SITE': 16, 'VAX_NAME': 17, 'RECVDATE': 18, 'STATE': 19, 'AGE_YRS': 20, 'CAGE_YR': 21, 'CAGE_MO': 22, 'SEX': 23, 'RPT_DATE': 24, 'SYMPTOM_TEXT': 25, 'DIED': 26, 'DATEDIED': 27, 'L_THREAT': 28, 'ER_VISIT': 29, 'HOSPITAL': 30, 'HOSPDAYS': 31, 'X_STAY': 32, 'DISABLE': 33, 'RECOVD': 34, 'VAX_DATE': 35, 'ONSET_DATE': 36, 'NUMDAYS': 37, 'LAB_DATA': 38, 'V_ADMINBY': 39, 'V_FUNDBY': 40, 'OTHER_MEDS': 41, 'CUR_ILL': 42, 'HISTORY': 43, 'PRIOR_VAX': 44, 'SPLTTYPE': 45, 'FORM_VERS': 46, 'TODAYS_DATE': 47, 'BIRTH_DEFECT': 48, 'OFC_VISIT': 49, 'ER_ED_VISIT': 50, 'ALLERGIES': 51}

# %%
pd.set_option('display.max_columns', None)

# %%
V2021_C = pd.DataFrame()
V2022_C = pd.DataFrame()

# %%
V2021_C = V2021_B.iloc[:,[0,1,3,5,7,9,11,12.13,14,18,20,23,25,26,27,33,34,35,36,37,48,]]
V2022_C = V2022_B.iloc[:,[0,1,3,5,7,9,11,12,13,14,18,20,23,25,26,27,33,34,35,36,37,48,]]

# %%
a = V2021_C
b = V2022_C
VMERGED_A = pd.concat([a,b] , join='inner')

# %%
VMERGED_B = VMERGED_A[VMERGED_A['VAX_TYPE']== 'COVID19']

# %%
med_age = VMERGED_B['AGE_YRS'].median()
med_num = VMERGED_B['NUMDAYS'].median()

# %%
med_age, med_num
# Out:
# (52.0, 1.0)

# %%
VMERGED_C =VMERGED_B.copy()

# %%
VMERGED_C['AGE_YRS']= VMERGED_C['AGE_YRS'].replace(np.nan,med_age).astype(int)
VMERGED_C['NUMDAYS']= VMERGED_C['NUMDAYS'].replace(np.nan,med_num).astype(int)

# %%
VMERGED_C['ONSET_DATE'] = pd.to_datetime(VMERGED_C['ONSET_DATE'])
VMERGED_C['VAX_DATE'] = pd.to_datetime(VMERGED_C['VAX_DATE'])

# %%
VDELTA = VMERGED_C['ONSET_DATE'] - pd.to_timedelta(VMERGED_C['NUMDAYS'],'D', errors='coerce')

# %%
VMERGED_C['VAX_DATE'] = VMERGED_C['VAX_DATE'].replace(np.nan,VDELTA[0])

# %%
VDELTAP = VMERGED_C['VAX_DATE'] + pd.to_timedelta(VMERGED_C['NUMDAYS'],'D', errors='coerce')

# %%
VMERGED_C['ONSET_DATE'] = VMERGED_C['ONSET_DATE'].replace(np.nan,VDELTAP[0])

# %%
VMERGED_D = VMERGED_C.replace(np.nan,'-').copy()

# %%
VMERGED_COV = VMERGED_D[VMERGED_D['VAX_TYPE']== 'COVID19']

# %%
a= VAXUS
b= VMERGED_COV

# %%
a['VAX_DATE'] = pd.to_datetime(a['VAX_DATE'])

# %%
VWTHDUP = pd.merge(a, b, on='VAX_DATE', how='outer').fillna(method='ffill')

# %%
VWTHDUP['VAX_DOSE_SERIES'] = VWTHDUP['VAX_DOSE_SERIES'].replace('','UNK')
VWTHDUP['SEX'] = VWTHDUP['SEX'].replace('U','UNK')
VWTHDUP['DIED'] = VWTHDUP['DIED'].replace('-','N')
VWTHDUP['RECOVD'] = VWTHDUP['RECOVD'].replace({'-':'UNK', 'U':'UNK'})
VWTHDUP['BIRTH_DEFECT'] = VWTHDUP['BIRTH_DEFECT'].replace('-','UNK')
VWTHDUP['DISABLE'] = VWTHDUP['DISABLE'].replace('-','UNK')

# %%
VWTHDUP['VAX_DOSE_SERIES'] = VWTHDUP['VAX_DOSE_SERIES'].astype('category')

# %%
VWTHDUP['VAX_DOSE_SERIES'].value_counts()
# Out:
# 1      557324
# 2      381624
# UNK    184199
# 3      125281
# 4       31129
# -        4779
# 5        2938
# 7+        402
# 6         231
# Name: VAX_DOSE_SERIES, dtype: int64

# %%
VWTHDUP = VWTHDUP.convert_dtypes()

# %%
VWTHDUP.iloc[:,[11,12,16,18,20,21,24]] = VWTHDUP.iloc[:,[11,12,16,18,20,21,24]].astype('category')

# %%
VWWTHDUP = VWTHDUP.drop(VWTHDUP.columns[[0,14,19]],axis=1)

# %%
start_date = '11/11/2019'
end_date ='12/30/2022'

# %%
mask = (VWWTHDUP['VAX_DATE'] > start_date) & (VWWTHDUP['VAX_DATE'] <= end_date)

# %%
VWWTHDUP = VWWTHDUP.loc[mask]

# %%
VWWTHDUP = VWWTHDUP.sort_values('VAX_DATE',ignore_index=True)

# %%
VWWTHDUP.to_csv('COVIDVAERS_WITH_DUPLICATES2021_2022.csv',index=False)

# %%
VXNODUP = VWWTHDUP.drop_duplicates(subset='VAERS_ID')

# %%
VXNODUP = VXNODUP.sort_values('VAX_DATE', ignore_index=True)

# %%
VXNODUP.to_csv('COVIDVAERS_NO_DUPLICATES2021_2022.csv',index=False)

# %%
# Validate with VWWTHDUP.isna.sum() , VWWTHDUP.info()

# %%
VWWTHDUP
# Out:
#           VAX_DATE  Administered_Daily  Administered_Cumulative  \
# 0       2019-11-14              131486                  5836901
# 1       2019-11-16              131486                  5836901
# 2       2019-11-25              131486                  5836901
# 3       2019-11-25              131486                  5836901
# 4       2019-11-28              131486                  5836901
# ...            ...                 ...                      ...
# 1286318 2022-12-30              238624                665570964
# 1286319 2022-12-30              238624                665570964
# 1286320 2022-12-30              238624                665570964
# 1286321 2022-12-30              238624                665570964
# 1286322 2022-12-30              238624                665570964
#
#          Administered_7_Day_Rolling_Average  VAERS_ID  \
# 0                                    424324   2457983
# 1                                    424324   1627193
# 2                                    424324    961860
# 3                                    424324    961860
# 4                                    424324   1391454
# ...                                     ...       ...
# 1286318                              167073   2547276
# 1286319                              167073   2547275
# 1286320                              167073   2547261
# 1286321                              167073   2547150
# 1286322                              167073   2547106
#
#                                            SYMPTOM1               SYMPTOM2  \
# 0                                            Eczema          Hand fracture
# 1                Maternal exposure during pregnancy                   Rash
# 2                                           Pyrexia                   Rash
# 3                                        Arthralgia                Fatigue
# 4                           Injection site erythema  Injection site warmth
# ...                                             ...                    ...
# 1286318                Expired product administered       No adverse event
# 1286319                Expired product administered       No adverse event
# 1286320                Expired product administered       No adverse event
# 1286321  Incorrect product formulation administered       No adverse event
# 1286322                 Incorrect dose administered                      -
#
#          SYMPTOM3 SYMPTOM4 SYMPTOM5 VAX_TYPE VAX_MANU VAX_DOSE_SERIES  \
# 0          Stress        -        -  COVID19  MODERNA               2
# 1               -        -        -  COVID19  MODERNA             UNK
# 2        Vomiting        -        -  COVID19  MODERNA               1
# 3        Headache  Myalgia   Nausea  COVID19  MODERNA               1
# 4         Myalgia        -        -  COVID19  MODERNA               1
# ...           ...      ...      ...      ...      ...             ...
# 1286318         -        -        -  COVID19  MODERNA               1
# 1286319         -        -        -  COVID19  MODERNA               1
# 1286320         -        -        -  COVID19  MODERNA               1
# 1286321         -        -        -  COVID19  MODERNA               3
# 1286322         -        -        -  COVID19  MODERNA               2
#
#          AGE_YRS SEX                                       SYMPTOM_TEXT DIED  \
# 0             65   F  Eczema flared up pretty badly/main areas affec...    N
# 1             39   F  Was pregnant; Rash; This spontaneous prospecti...    N
# 2             31   F  Headache, Myalgia, Arthralgia, Fever, Rash, Na...    N
# 3             31   F  Headache, Myalgia, Arthralgia, Fever, Rash, Na...    N
# 4             37   M  Myalgia Localized injection site redness and w...    N
# ...          ...  ..                                                ...  ...
# 1286318       66   M  Vaccine expired on 11/27/22 and was administer...    N
# 1286319       52   M  Vaccine expired on 11/27/22 and was administer...    N
# 1286320       44   M  Vaccine expired on 11/27/22 and was administer...    N
# 1286321        2   F  NO ADVERSE EFFECT THIRD DOSE OF MONOVALENT MOD...    N
# 1286322        3   M  not an adverse event, however incident reached...    N
#
#         DISABLE RECOVD ONSET_DATE  NUMDAYS BIRTH_DEFECT
# 0             Y    UNK 2020-07-01      230          UNK
# 1           UNK    UNK 2020-12-20        1          UNK
# 2           UNK      Y 2020-12-26      397          UNK
# 3           UNK      Y 2020-12-26      397          UNK
# 4           UNK      N 2021-01-06      405          UNK
# ...         ...    ...        ...      ...          ...
# 1286318     UNK    UNK 2022-12-30        0          UNK
# 1286319     UNK    UNK 2022-12-30        0          UNK
# 1286320     UNK    UNK 2022-12-30        0          UNK
# 1286321     UNK    UNK 2022-12-01        1          UNK
# 1286322     UNK    UNK 2022-12-30        0          UNK
#
# [1286323 rows x 22 columns]

# %%
VXNODUP.shape[0]
# Out:
# 892140

# %%
VWWTHDUP[VWWTHDUP['VAERS_ID']==2396371]
# Out:
#           VAX_DATE  Administered_Daily  Administered_Cumulative  \
# 1254746 2022-05-27              449666                590963680
# 1254774 2022-05-27              449666                590963680
# 1254775 2022-05-27              449666                590963680
# 1254776 2022-05-27              449666                590963680
# 1254777 2022-05-27              449666                590963680
# ...            ...                 ...                      ...
# 1254951 2022-05-27              449666                590963680
# 1254952 2022-05-27              449666                590963680
# 1254953 2022-05-27              449666                590963680
# 1254954 2022-05-27              449666                590963680
# 1254955 2022-05-27              449666                590963680
#
#          Administered_7_Day_Rolling_Average  VAERS_ID  \
# 1254746                              367259   2396371
# 1254774                              367259   2396371
# 1254775                              367259   2396371
# 1254776                              367259   2396371
# 1254777                              367259   2396371
# ...                                     ...       ...
# 1254951                              367259   2396371
# 1254952                              367259   2396371
# 1254953                              367259   2396371
# 1254954                              367259   2396371
# 1254955                              367259   2396371
#
#                                      SYMPTOM1                        SYMPTOM2  \
# 1254746            Mean cell volume increased  Mean platelet volume increased
# 1254774               Prothrombin time normal  Red blood cell count decreased
# 1254775               Prothrombin time normal  Red blood cell count decreased
# 1254776               Prothrombin time normal  Red blood cell count decreased
# 1254777         Specific gravity urine normal        Subarachnoid haemorrhage
# ...                                       ...                             ...
# 1254951                             Dizziness            Drug screen positive
# 1254952             Cerebral arteriosclerosis        Cerebrovascular accident
# 1254953             Cerebral arteriosclerosis        Cerebrovascular accident
# 1254954             Cerebral arteriosclerosis        Cerebrovascular accident
# 1254955  Blood urea nitrogen/creatinine ratio               Blood urea normal
#
#                                    SYMPTOM3  \
# 1254746                   Memory impairment
# 1254774  Red cell distribution width normal
# 1254775  Red cell distribution width normal
# 1254776  Red cell distribution width normal
# 1254777                          Tenderness
# ...                                     ...
# 1254951                      Echocardiogram
# 1254952                Chest X-ray abnormal
# 1254953                Chest X-ray abnormal
# 1254954                Chest X-ray abnormal
# 1254955                  Blood urine absent
#
#                                   SYMPTOM4                    SYMPTOM5  \
# 1254746              Mental status changes     Metabolic function test
# 1254774        Scan with contrast abnormal           Sinus bradycardia
# 1254775        Scan with contrast abnormal           Sinus bradycardia
# 1254776        Scan with contrast abnormal           Sinus bradycardia
# 1254777                   Thyroxine normal  Transient ischaemic attack
# ...                                    ...                         ...
# 1254951         Electrocardiogram abnormal        Electroencephalogram
# 1254952  Computerised tomogram head normal        Condition aggravated
# 1254953  Computerised tomogram head normal        Condition aggravated
# 1254954  Computerised tomogram head normal        Condition aggravated
# 1254955   Brain natriuretic peptide normal       Carbon dioxide normal
#
#         VAX_TYPE         VAX_MANU VAX_DOSE_SERIES  AGE_YRS SEX  \
# 1254746  COVID19  PFIZER\BIONTECH               1       54   M
# 1254774  COVID19  PFIZER\BIONTECH               2       54   M
# 1254775  COVID19  PFIZER\BIONTECH               3       54   M
# 1254776  COVID19  PFIZER\BIONTECH               4       54   M
# 1254777  COVID19  PFIZER\BIONTECH               1       54   M
# ...          ...              ...             ...      ...  ..
# 1254951  COVID19  PFIZER\BIONTECH               1       54   M
# 1254952  COVID19  PFIZER\BIONTECH               3       54   M
# 1254953  COVID19  PFIZER\BIONTECH               2       54   M
# 1254954  COVID19  PFIZER\BIONTECH               1       54   M
# 1254955  COVID19  PFIZER\BIONTECH               4       54   M
#
#                                               SYMPTOM_TEXT DIED DISABLE  \
# 1254746  ED note by Dr. on 6/9/22: "Date:  6/9/2022 Mea...    N     UNK
# 1254774  ED note by Dr. on 6/9/22: "Date:  6/9/2022 Mea...    N     UNK
# 1254775  ED note by Dr. on 6/9/22: "Date:  6/9/2022 Mea...    N     UNK
# 1254776  ED note by Dr. on 6/9/22: "Date:  6/9/2022 Mea...    N     UNK
# 1254777  ED note by Dr. on 6/9/22: "Date:  6/9/2022 Mea...    N     UNK
# ...                                                    ...  ...     ...
# 1254951  ED note by Dr. on 6/9/22: "Date:  6/9/2022 Mea...    N     UNK
# 1254952  ED note by Dr. on 6/9/22: "Date:  6/9/2022 Mea...    N     UNK
# 1254953  ED note by Dr. on 6/9/22: "Date:  6/9/2022 Mea...    N     UNK
# 1254954  ED note by Dr. on 6/9/22: "Date:  6/9/2022 Mea...    N     UNK
# 1254955  ED note by Dr. on 6/9/22: "Date:  6/9/2022 Mea...    N     UNK
#
#         RECOVD ONSET_DATE  NUMDAYS BIRTH_DEFECT
# 1254746    UNK 2022-06-09       13          UNK
# 1254774    UNK 2022-06-09       13          UNK
# 1254775    UNK 2022-06-09       13          UNK
# 1254776    UNK 2022-06-09       13          UNK
# 1254777    UNK 2022-06-09       13          UNK
# ...        ...        ...      ...          ...
# 1254951    UNK 2022-06-09       13          UNK
# 1254952    UNK 2022-06-09       13          UNK
# 1254953    UNK 2022-06-09       13          UNK
# 1254954    UNK 2022-06-09       13          UNK
# 1254955    UNK 2022-06-09       13          UNK
#
# [80 rows x 22 columns]
